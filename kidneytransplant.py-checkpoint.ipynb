# %%
import tkinter as tk
from tkinter import *
root= tk.Tk()
root.geometry('700x600')
root.title('Kidney Transplant App')

def switch(indicator,page):
    
    for child in nav.winfo_children():
        if isinstance(child,tk.Label):
            child['bg']='SystemButtonFace'
            
    indicator['bg']='#0097e8'
    
    for fm in main_fm.winfo_children():
        fm.destroy()
        root.update()
    
    page()


    
    

nav=tk.Frame(root)
donor=tk.Button(nav,text='Donor',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                command=lambda:switch(indicator=d_indicator,page=donor_page))
donor.place(x=0,y=0,width=100)
d_indicator=tk.Label(nav,bg='#0097e8')
d_indicator.place(x=15,y=35,width=75,height=2)

recipient=tk.Button(nav,text='Recipient',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                    command=lambda:switch(indicator=r_indicator,page=recipient_page))
recipient.place(x=125,y=0,width=150)
r_indicator=tk.Label(nav)
r_indicator.place(x=150,y=35,width=95,height=2)

hospital=tk.Button(nav,text='Hospital',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                   command=lambda:switch(indicator=h_indicator,page=hospital_page))
hospital.place(x=250,y=0,width=295)
h_indicator=tk.Label(nav)
h_indicator.place(x=360,y=35,width=75,height=2)

nav.pack()
nav.pack_propagate(False)
nav.configure(width=500,height=45)

def donor_page():
    
    donor_page_fm=tk.Frame(main_fm)

    label0 = Label(root, text="Donor Form",width=20,fg="green",font=("bold",27))
    label0.place(x=100,y=53)

    label = Label(root, text="Donor Name:")
    label.place(x=20,y=130)
    entry = Entry(root,width=40)
    entry.place(x=105,y=130)

    label1 = Label(root, text="Father Name:")
    label1.place(x=20,y=170)
    entry1 = Entry(root,width=40)
    entry1.place(x=105,y=170)

    label2 = Label(root, text="Address:")
    label2.place(x=20,y=210)
    entry2 = Entry(root,width=40)
    entry2.place(x=105,y=210)

    label3 = Label(root, text="Email:")
    label3.place(x=20,y=250)
    entry3 = Entry(root,width=40)
    entry3.place(x=105,y=250)

    label4 = Label(root, text="Mobile No:")
    label4.place(x=20,y=290)
    entry4 = Entry(root,width=40)
    entry4.place(x=105,y=290)
 
    label5 = Label(root, text="DOB:")
    label5.place(x=20,y=330)
    entry5 = Entry(root,width=40)
    entry5.place(x=105,y=330)

    label6 = Label(root, text="Age:")
    label6.place(x=20,y=370)
    entry6 = Entry(root,width=40)
    entry6.place(x=105,y=370)

    label7 = Label(root, text="Gender:")
    label7.place(x=20,y=410)
    entry7 = Entry(root,width=40)
    entry7.place(x=105,y=410)

    label8 = Label(root, text="HLA Value:")
    label8.place(x=20,y=450)
    entry8 = Entry(root,width=40)
    entry8.place(x=105,y=450)

    label9 = Label(root, text="Blood Group:")
    label9.place(x=20,y=490)
    entry9 = Entry(root,width=40)
    entry9.place(x=105,y=490)



    send_button = Button(root, text="Submit")
    send_button.place(x=80,y=550)


    donor_page_fm.pack(fill=tk.BOTH,expand=True)
    
    
def recipient_page():
    
    recipient_page_fm=tk.Frame(main_fm)
    
    recipient_page_lb=tk.Label( recipient_page_fm,text='Recipient Page',font=('Arial',25),fg='#0097e8')
    recipient_page_lb.pack(pady=80)

    recipient_page_fm.pack(fill=tk.BOTH,expand=True) 
    

    
    
def hospital_page():
    
    hospital_page_fm=tk.Frame(main_fm)
    
    hospital_page_lb=tk.Label(hospital_page_fm,text='Hospital Page',font=('Arial',25),fg='#0097e8')
    hospital_page_lb.pack(pady=80)

    hospital_page_fm.pack(fill=tk.BOTH,expand=True)      
    
    

main_fm=tk.Frame(root)
main_fm.pack(fill=tk.BOTH,expand=True)


donor_page()
root.mainloop()

# %%
import tkinter as tk
from tkinter import *
from tkinter import PhotoImage
from PIL import ImageTk,Image
root= tk.Tk()
root.geometry('700x600')
root.title('Kidney Transplant App')


def home_page():
    
        home_page_fm=tk.Frame(root,width=700,height=600)
        home_page_fm.place(x=0,y=0)
        
#         image_path=PhotoImage(file="C:/Users/ITCommplex/Desktop/python code/kidney.jpg")
#         bg_image=tk.Label(home_page_fm,image= image_path)
#         bg_image.place(relheight=1,relwidth=1)
        
        file_path="C:/Users/ITCommplex/Desktop/python code/gift.png"
        image=Image.open(file_path)
        resized_image=image.resize((100,100))
        image=ImageTk.PhotoImage(resized_image)
        img_label=Label(root,image=image)
        img_label.place(x=590,y=70)
    
        home=tk.Button(home_page_fm,text='Home',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                   comman=home_page)
        home.place(x=0,y=0,width=100)
        
        donor = tk.Button(home_page_fm, text='Donor', font=('Arial', 18), bd=0, fg='#0097e8', activeforeground='#0097e8', command=donor_page)
        donor.place(x=125, y=0, width=100)


        recipient=tk.Button(home_page_fm,text='Recipient',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                    command=recipient_page)
        recipient.place(x=250,y=0,width=150)


        hospital=tk.Button(home_page_fm,text='Hospital',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                   command=hospital_page)
        hospital.place(x=375,y=0,width=295)





def donor_page():
    
    donor_page_fm = tk.Frame(root, width=700, height=600)
    donor_page_fm.place(x=0, y=0)

    
    home=tk.Button(donor_page_fm,text='Home',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                   comman=home_page)
    home.place(x=0,y=0,width=100)
        
    donor = tk.Button(donor_page_fm, text='Donor', font=('Arial', 18), bd=0, fg='#0097e8', activeforeground='#0097e8', command=donor_page)
    donor.place(x=125, y=0, width=100)


    recipient=tk.Button(donor_page_fm,text='Recipient',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                    command=recipient_page)
    recipient.place(x=250,y=0,width=150)


    hospital=tk.Button(donor_page_fm,text='Hospital',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                   command=hospital_page)
    hospital.place(x=375,y=0,width=295)
    
    label0 = Label(donor_page_fm, text="Donor Form",width=20,fg="green",font=("bold",27))
    label0.place(x=100,y=53)

    label = Label(donor_page_fm, text="Donor Name:")
    label.place(x=20,y=130)
    entry = Entry(donor_page_fm,width=40)
    entry.place(x=105,y=130)

    label1 = Label(donor_page_fm, text="Father Name:")
    label1.place(x=20,y=170)
    entry1 = Entry(donor_page_fm,width=40)
    entry1.place(x=105,y=170)

    label2 = Label(donor_page_fm, text="Address:")
    label2.place(x=20,y=210)
    entry2 = Entry(donor_page_fm,width=40)
    entry2.place(x=105,y=210)

    label3 = Label(donor_page_fm, text="Email:")
    label3.place(x=20,y=250)
    entry3 = Entry(donor_page_fm,width=40)
    entry3.place(x=105,y=250)

    label4 = Label(donor_page_fm, text="Mobile No:")
    label4.place(x=20,y=290)
    entry4 = Entry(donor_page_fm,width=40)
    entry4.place(x=105,y=290)
 
    label5 = Label(donor_page_fm, text="DOB:")
    label5.place(x=20,y=330)
    entry5 = Entry(donor_page_fm,width=40)
    entry5.place(x=105,y=330)

    label6 = Label(donor_page_fm, text="Age:")
    label6.place(x=20,y=370)
    entry6 = Entry(donor_page_fm,width=40)
    entry6.place(x=105,y=370)

    label7 = Label(donor_page_fm, text="Gender:")
    label7.place(x=20,y=410)
    entry7 = Entry(donor_page_fm,width=40)
    entry7.place(x=105,y=410)

    label8 = Label(donor_page_fm, text="HLA Value:")
    label8.place(x=20,y=450)
    entry8 = Entry(donor_page_fm,width=40)
    entry8.place(x=105,y=450)

    label9 = Label(donor_page_fm, text="Blood Group:")
    label9.place(x=20,y=490)
    entry9 = Entry(donor_page_fm,width=40)
    entry9.place(x=105,y=490)



    send_button = Button(donor_page_fm, text="Submit")
    send_button.place(x=80,y=550)



    
    
    
def recipient_page():
    
        recipient_page_fm= tk.Frame(root,width=700,height=600)
        recipient_page_fm.place(x=0,y=0)
    
        home=tk.Button( recipient_page_fm,text='Home',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                   comman=home_page)
        home.place(x=0,y=0,width=100)
        
        donor = tk.Button( recipient_page_fm, text='Donor', font=('Arial', 18), bd=0, fg='#0097e8', activeforeground='#0097e8', command=donor_page)
        donor.place(x=125, y=0, width=100)


        recipient=tk.Button( recipient_page_fm,text='Recipient',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                    command=recipient_page)
        recipient.place(x=250,y=0,width=150)


        hospital=tk.Button( recipient_page_fm,text='Hospital',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                   command=hospital_page)
        hospital.place(x=375,y=0,width=295)
        
        
        label0 = Label(recipient_page_fm, text="Recipient Form",width=20,fg="green",font=("bold",27))
        label0.place(x=100,y=53)

        label = Label(recipient_page_fm, text="RecipientName:")
        label.place(x=20,y=130)
        entry = Entry(recipient_page_fm,width=40)
        entry.place(x=105,y=130)

        label1 = Label(recipient_page_fm, text="Father Name:")
        label1.place(x=20,y=170)
        entry1 = Entry(recipient_page_fm,width=40)
        entry1.place(x=105,y=170)

        label2 = Label(recipient_page_fm, text="Address:")
        label2.place(x=20,y=210)
        entry2 = Entry(recipient_page_fm,width=40)
        entry2.place(x=105,y=210)

        label3 = Label(recipient_page_fm, text="Email:")
        label3.place(x=20,y=250)
        entry3 = Entry(recipient_page_fm,width=40)
        entry3.place(x=105,y=250)

        label4 = Label(recipient_page_fm, text="Mobile No:")
        label4.place(x=20,y=290)
        entry4 = Entry(recipient_page_fm,width=40)
        entry4.place(x=105,y=290)
 
        label5 = Label(recipient_page_fm, text="DOB:")
        label5.place(x=20,y=330)
        entry5 = Entry(recipient_page_fm,width=40)
        entry5.place(x=105,y=330)

        label6 = Label(recipient_page_fm, text="Age:")
        label6.place(x=20,y=370)
        entry6 = Entry(recipient_page_fm,width=40)
        entry6.place(x=105,y=370)

        label7 = Label(recipient_page_fm, text="Gender:")
        label7.place(x=20,y=410)
        entry7 = Entry(recipient_page_fm,width=40)
        entry7.place(x=105,y=410)

        label8 = Label(recipient_page_fm, text="HLA Value:")
        label8.place(x=20,y=450)
        entry8 = Entry(recipient_page_fm,width=40)
        entry8.place(x=105,y=450)

        label9 = Label(recipient_page_fm, text="Blood Group:")
        label9.place(x=20,y=490)
        entry9 = Entry(recipient_page_fm,width=40)
        entry9.place(x=105,y=490)



        send_button = Button(recipient_page_fm, text="Submit")
        send_button.place(x=80,y=550)





def hospital_page():
    
        hospital_page_fm=tk.Frame(root,width=700,height=600)
        hospital_page_fm.place(x=0,y=0)
    
        home=tk.Button(  hospital_page_fm,text='Home',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                   comman=home_page)
        home.place(x=0,y=0,width=100)
        
        donor = tk.Button(  hospital_page_fm, text='Donor', font=('Arial', 18), bd=0, fg='#0097e8', activeforeground='#0097e8', command=donor_page)
        donor.place(x=125, y=0, width=100)


        recipient=tk.Button( hospital_page_fm,text='Recipient',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                    command=recipient_page)
        recipient.place(x=250,y=0,width=150)


        hospital=tk.Button( hospital_page_fm,text='Hospital',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
                   command=hospital_page)
        hospital.place(x=375,y=0,width=295)



home_page()
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[12], line 242
#     236         hospital=tk.Button( hospital_page_fm,text='Hospital',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
#     237                    command=hospital_page)
#     238         hospital.place(x=375,y=0,width=295)
# --> 242 home_page()
#     243 root.mainloop()
#
# Cell In[12], line 23, in home_page()
#      21 resized_image=image.resize((100,100))
#      22 image=ImageTk.PhotoImage(resized_image)
# ---> 23 img_label=Label(root,image=image)
#      24 img_label.place(x=590,y=70)
#      26 home=tk.Button(home_page_fm,text='Home',font=('Arial',18),bd=0,fg='#0097e8',activeforeground='#0097e8',
#      27            comman=home_page)
#
# File C:\ProgramData\anaconda3\Lib\tkinter\__init__.py:3214, in Label.__init__(self, master, cnf, **kw)
# ...

# %%
from tkinter import *
import hashlib
import smtplib
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
from email.mime.multipart import MIMEMultipart
from email.message import EmailMessage
from tkinter import messagebox
from PIL import ImageTk,Image
from tkinter import filedialog
import base64
import os



root = Tk()
root.title('Addmission Form')
file_path="C:/Users/ITCommplex/Desktop/python code/gift.png"
image=Image.open(file_path)
resized_image=image.resize((100,100))
image=ImageTk.PhotoImage(resized_image)
img_label=Label(root,image=image)
img_label.place(x=590,y=70)
root.geometry('700x800')

root.mainloop()
